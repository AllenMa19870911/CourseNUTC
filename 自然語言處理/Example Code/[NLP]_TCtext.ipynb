# %%
import os
from google.colab import drive
drive.mount('/content/drive')
path=os.chdir('/content/drive/MyDrive/自然語言處理')
with open('news.txt', mode='r') as file:
  text=file.read()
  #print(text)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#jieba全模式, 返回generator
import jieba
text="土耳其敘利亞強震過後三個星期，災區中的災區敘利亞，狀況脆弱，聯合國救援車隊抵達，初步估計全國370萬兒童，等於整個敘利亞的下一代，缺乏基本飲食飲水與住房。土耳其災區則是餘震頻傳，災區倖存者一無所有，想工作賺錢都沒辦法，總統艾爾多安卻在這時堅持：五月中如期辦大選。"
generator = jieba.cut(text, cut_all=True)
print(generator)
for i in generator:
  print(i)

# %%
#jieba全模式, 返回list
import jieba
text="土耳其敘利亞強震過後三個星期，災區中的災區敘利亞，狀況脆弱，聯合國救援車隊抵達，初步估計全國370萬兒童，等於整個敘利亞的下一代，缺乏基本飲食飲水與住房。土耳其災區則是餘震頻傳，災區倖存者一無所有，想工作賺錢都沒辦法，總統艾爾多安卻在這時堅持：五月中如期辦大選。"
seg_list = jieba.lcut(text, cut_all=True)
print(seg_list)
for i in seg_list:
  print(i)

# %%
#jieba精準模式, 返回list
import jieba
text="我們在野生動物園玩"
text2="國立台中科技大學位於台中, 台灣大學研究所, 台中逢甲夜市, 台中有很多餐廳, 台中天氣很好"
text3="土耳其敘利亞強震過後三個星期，災區中的災區敘利亞，狀況脆弱，聯合國救援車隊抵達，初步估計全國370萬兒童，等於整個敘利亞的下一代，缺乏基本飲食飲水與住房。土耳其災區則是餘震頻傳，災區倖存者一無所有，想工作賺錢都沒辦法，總統艾爾多安卻在這時堅持：五月中如期辦大選。"
seg_list = jieba.lcut(text, cut_all=False)
print(seg_list)
seg_list2 = jieba.lcut(text2, cut_all=False)
print(seg_list2)
seg_list3 = jieba.lcut(text3, cut_all=False)
print(seg_list3)
print("---------------------------------------------------------------------------------------------------------------")
seg_list = jieba.lcut(text, cut_all=False, HMM=False)
print(seg_list)
seg_list2 = jieba.lcut(text2, cut_all=False, HMM=False)
print(seg_list2)
seg_list3 = jieba.lcut(text3, cut_all=False, HMM=False)
print(seg_list3)
# Out:
# ['我們', '在', '野生', '動物園', '玩']
# ['國立', '台', '中', '科技', '大學位', '於', '台', '中', ',', ' ', '台灣', '大學', '研究所', ',', ' ', '台', '中', '逢甲', '夜市', ',', ' ', '台中', '有', '很多', '餐廳', ',', ' ', '台中', '天氣', '很', '好']
# ['土耳其', '敘利亞', '強震', '過後三個', '星期', '，', '災區', '中', '的', '災區', '敘利亞', '，', '狀況', '脆弱', '，', '聯合國', '救援', '車隊', '抵達', '，', '初步', '估計', '全國', '370', '萬兒童', '，', '等', '於', '整個', '敘利亞', '的', '下一代', '，', '缺乏', '基本', '飲食', '飲水', '與', '住房', '。', '土耳其', '災區則', '是', '餘震', '頻傳', '，', '災區', '倖', '存者', '一', '無', '所有', '，', '想', '工作', '賺', '錢', '都', '沒', '辦法', '，', '總統', '艾爾多安', '卻', '在', '這時', '堅持', '：', '五月', '中', '如期', '辦大選', '。']
# ---------------------------------------------------------------------------------------------------------------
# ['我', '們', '在', '野生', '動', '物', '園', '玩']
# ['國', '立', '台', '中', '科技', '大', '學', '位', '於', '台', '中', ',', ' ', '台', '灣', '大', '學', '研究所', ',', ' ', '台', '中', '逢甲', '夜市', ',', ' ', '台', '中', '有', '很多', '餐', '廳', ',', ' ', '台', '中', '天', '氣', '很', '好']
# ...

# %%
#jieba paddle模式, 返回list
import jieba
text="國立台中科技大學位於台中, 台中逢甲夜市, 台中有很多餐廳, 台中天氣很好"
seg_list = jieba.lcut(text, use_paddle=True)
print(seg_list)
# Out:
# ['國立', '台', '中', '科技', '大學位', '於', '台', '中', ',', ' ', '台', '中', '逢甲', '夜市', ',', ' ', '台中', '有', '很多', '餐廳', ',', ' ', '台中', '天氣', '很', '好']

# %%
#jieba搜尋引擎模式, 返回list
import jieba
text="我們在野生動物園玩"
text2="國立台中科技大學位於台中, 台灣大學研究所, 台聯大研究所, 台中逢甲夜市, 台中有很多餐廳, 台中天氣很好"
text3="土耳其敘利亞強震過後三個星期，災區中的災區敘利亞，狀況脆弱，聯合國救援車隊抵達，初步估計全國370萬兒童，等於整個敘利亞的下一代，缺乏基本飲食飲水與住房。土耳其災區則是餘震頻傳，災區倖存者一無所有，想工作賺錢都沒辦法，總統艾爾多安卻在這時堅持：五月中如期辦大選。"
seg_list = jieba.lcut_for_search(text)
print(seg_list)
seg_list2 = jieba.lcut_for_search(text2)
print(seg_list2)
seg_list3 = jieba.lcut_for_search(text3)
print(seg_list3)
# Out:
# ['我們', '在', '野生', '動物園', '玩']
# ['國立', '台', '中', '科技', '大學位', '於', '台', '中', ',', ' ', '台灣', '大學', '研究', '研究所', ',', ' ', '台聯大', '研究', '研究所', ',', ' ', '台', '中', '逢甲', '夜市', ',', ' ', '台中', '有', '很多', '餐廳', ',', ' ', '台中', '天氣', '很', '好']
# ['土耳其', '敘利亞', '強震', '過後三個', '星期', '，', '災區', '中', '的', '災區', '敘利亞', '，', '狀況', '脆弱', '，', '聯合國', '救援', '車隊', '抵達', '，', '初步', '估計', '全國', '370', '萬兒童', '，', '等', '於', '整個', '敘利亞', '的', '一代', '下一代', '，', '缺乏', '基本', '飲食', '飲水', '與', '住房', '。', '土耳其', '災區則', '是', '餘震', '頻傳', '，', '災區', '倖', '存者', '一', '無', '所有', '，', '想', '工作', '賺', '錢', '都', '沒', '辦法', '，', '總統', '艾爾多安', '卻', '在', '這時', '堅持', '：', '五月', '中', '如期', '辦大選', '。']

# %%
import os
#jieba讀取詞典以及操作詞典
jieba.load_userdict('dict.txt')
text="我們在野生動物園玩"
text2="國立台中科技大學位於台中, 台灣大學研究所, 陽光大學, 台聯大研究所, 台師大附中, 台中逢甲夜市, 台中有很多餐廳, 台中天氣很好"
text3="土耳其敘利亞強震過後三個星期，災區中的災區敘利亞，狀況脆弱，聯合國救援車隊抵達，初步估計全國370萬兒童，等於整個敘利亞的下一代，缺乏基本飲食飲水與住房。土耳其災區則是餘震頻傳，災區倖存者一無所有，想工作賺錢都沒辦法，總統艾爾多安卻在這時堅持：五月中如期辦大選。"
seg_list = jieba.lcut(text, cut_all=False, HMM=False)
print(seg_list)
seg_list2 = jieba.lcut(text2, cut_all=False)
print(seg_list2)
seg_list3 = jieba.lcut(text3, cut_all=False)
print(seg_list3)
jieba.add_word('陽光大學')
jieba.add_word('台師大附中', 100, "N")
seg_list4 = jieba.lcut_for_search(text2)
print(seg_list4)
# Out:
# ['我', '們', '在', '野生', '動', '物', '園', '玩']
# ['國立', '台', '中', '科技', '大學位', '於', '台', '中', ',', ' ', '台灣', '大學', '研究所', ',', ' ', '陽', '光大', '學', ',', ' ', '台聯大', '研究所', ',', ' ', '台師', '大', '附中', ',', ' ', '台', '中', '逢甲', '夜市', ',', ' ', '台中', '有', '很多', '餐廳', ',', ' ', '台中', '天氣', '很', '好']
# ['土耳其', '敘利亞', '強震', '過後三個', '星期', '，', '災區', '中', '的', '災區', '敘利亞', '，', '狀況', '脆弱', '，', '聯合國', '救援', '車隊', '抵達', '，', '初步', '估計', '全國', '370', '萬兒童', '，', '等', '於', '整個', '敘利亞', '的', '下一代', '，', '缺乏', '基本', '飲食', '飲水', '與', '住房', '。', '土耳其', '災區則', '是', '餘震', '頻傳', '，', '災區', '倖', '存者', '一', '無', '所有', '，', '想', '工作', '賺', '錢', '都', '沒', '辦法', '，', '總統', '艾爾多安', '卻', '在', '這時', '堅持', '：', '五月', '中', '如期', '辦大選', '。']
# ['國立', '台', '中', '科技', '大學位', '於', '台', '中', ',', ' ', '台灣', '大學', '研究', '研究所', ',', ' ', '光大', '陽光大學', ',', ' ', '台聯大', '研究', '研究所', ',', ' ', '附中', '台師大附中', ',', ' ', '台', '中', '逢甲', '夜市', ',', ' ', '台中', '有', '很多', '餐廳', ',', ' ', '台中', '天氣', '很', '好']

# %%
import os
with open('news.txt', mode='r') as file:
  text=file.read()
  #print(text)
  seg_list = jieba.lcut(text, cut_all=False)
  print(seg_list)
# Out:
# ['土敘', '強震', '過後三個', '星期', '，', '災區', '中', '的', '災區', '敘利亞', '，', '狀況', '脆弱', '，', '聯合國', '救援', '車隊', '抵達', '，', '初步', '估計', '全國', '370', '萬兒童', '，', '等', '於', '整個', '敘利亞', '的', '下一代', '，', '缺乏', '基本', '飲食', '飲水', '與', '住房', '。', '土耳其', '災區則', '是', '餘震', '頻傳', '，', '災區', '倖', '存者', '一', '無', '所有', '，', '想', '工作', '賺', '錢', '都', '沒', '辦法', '，', '總統', '艾爾多安', '卻', '在', '這時', '堅持', '：', '五月', '中', '如期', '辦大選', '。', '歐美', '分析', '他會用', '各種', '手法', '干', '預選舉', '，', '但', '民意', '已到', '谷底', '，', '結果', '難料', '。', '災區', '仍', '有', '零星', '奇', '蹟', '出現', '，', '受困', '21', '天', '的', '一匹', '土耳其', '馬', '竟', '存活', '，', '還能', '自己', '爬', '上瓦礫', '堆', '。', '\n', '\n', '重機', '具開', '挖', '廢墟', '前一刻', '，', '才', '發現', '馬', '房', '沒塌', '！', '土耳其', '阿德', '亞曼省', '(', 'Ad', 'ı', 'yaman', ')', '在', '大震', '後', '21', '天', '，', '再', '現奇', '蹟', '。', '受困', '3', '週', '的', '棕馬', '還能', '自己', '走上', '一層', '樓', '高', '的', '瓦礫', '堆', '！', '\n', '\n', '路透社', '記者', '：', '「', '(', '祖孫', ')', '再度', '團聚', '，', '3', '週前', '他們', '一同', '
# ...

# %%
#jieba TFIDF關鍵詞
import jieba
import jieba.analyse
file_name = 'news.txt'
sentence = open(file_name, 'r').read()
tags = jieba.analyse.extract_tags(sentence, topK=20)
print(tags)
for x, w in jieba.analyse.extract_tags(sentence, withWeight=True, topK=20):
     print('%s %s' % (x, w))
# Out:
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 1.618 seconds.
# DEBUG:jieba:Loading model cost 1.618 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.
# ['土耳其', '艾爾多安', '敘利亞', '地震', '災區', '總統', '歐盟', '聯合國', '災民', '老爺爺', '評論', '網站', 'Breakingviews', '創辦', '狄克森', '基利', '車隊', '抵達', '估計', '370']
# 土耳其 0.2696326747327016
# 艾爾多安 0.2169211845284274
# 敘利亞 0.12051176918245968
# 地震 0.11387308262403226
# 災區 0.09640941534596774
# 總統 0.09640941534596774
# 歐盟 0.09640941534596774
# 聯合國 0.0723070615094758
# 災民 0.0723070615094758
# 老爺爺 0.0723070615094758
# 評論 0.0723070615094758
# 網站 0.0723070615094758
# Breakingviews 0.0723070615094758
# 創辦 0.0723070615094758
# 狄克森 0.0723070615094758
# 基利 0.048826282994758066
# 車隊 0.04820470767298387
# ...

# %%
#jieba 詞性標註
import jieba
import jieba.posseg as pseg
file_name = 'news.txt'
sentence = open(file_name, 'r').read()
words = pseg.cut(sentence)
for word, flag in words:
  print('%s %s' % (word, flag))
# Out:
# 土 n
# 敘強 v
# 震過 v
# 後 nr
# 三個 m
# 星期 t
# ， x
# 災區 n
# 中 f
# 的 uj
# 災區 n
# 敘利亞 ns
# ， x
# 狀況 n
# 脆弱 a
# ， x
# 聯合國 nt
# 救援 vn
# 車隊 n
# 抵達 v
# ， x
# 初步 d
# 估計 v
# 全國 n
# 370 m
# 萬兒 m
# 童 n
# ， x
# 等 u
# 於 nr
# 整個 b
# 敘利亞 ns
# 的 uj
# 下一代 t
# ， x
# 缺乏 v
# 基本 n
# 飲食 n
# 飲水 n
# 與 p
# 住房 n
# 。 x
# 土耳其 ns
# 災區 n
# 則 d
# 是 v
# 餘震頻 nr
# 傳 v
# ， x
# 災 n
# 區 n
# 倖 zg
# 存 v
# 者 k
# 一 m
# 無 v
# 所有 b
# ， x
# 想 v
# 工作 vn
# 賺 v
# 錢 n
# 都 d
# 沒辦 v
# 法 n
# ， x
# 總統 n
# 艾爾多安 nrt
# 卻 d
# 在 p
# 這時 r
# 堅持 v
# ： x
# 五月 t
# 中 f
# 如期 t
# 辦大 v
# 選 v
# 。 x
# 歐美 ns
# 分析 vn
# 他 r
# 會 v
# 用 p
# 各種 r
# 手法 n
# 干 v
# 預選 v
# 舉 v
# ， x
# 但 c
# 民意 n
# 已 d
# 到 v
# 谷底 t
# ， x
# 結果 n
# 難料 n
# 。 x
# 災區 n
# 仍 d
# 有 v
# 零星 n
# 奇 nr
# 蹟 zg
# 出 v
# 現 tg
# ， x
# 受困 v
# 21 m
# 天 q
# 的 uj
# 一匹 m
# 土耳其 ns
# 馬竟 d
# 存活 vn
# ， x
# 還 d
# 能 v
# 自己 r
# 爬 v
# 上瓦 ns
# 礫堆 n
# 。 x
#
#  x
#
#  x
# 重機 n
# 具開 v
# 挖 v
# 廢墟 n
# 前一刻 i
# ， x
# 才 d
# 發現 v
# 馬房 n
# 沒塌 v
# ！ x
# 土耳其 ns
# 阿德 nrt
# 亞曼省 ns
# ( x
# Ad eng
# ı x
# yaman eng
# ) x
# 在 p
# ...

# %%
#jieba 搜尋詞在文件中的位置
file_name = 'news.txt'
sentence = open(file_name, 'r', encoding="utf-8").read()
result = jieba.tokenize(u'土耳其', sentence)
for tk in result:
  print("word %s\t\t start: %d \t\t end:%d" % (tk[0],tk[1],tk[2]))
# Out:
# word 土耳其		 start: 0 		 end:3

# %%
import nltk # 載入nltk 套件
nltk.download('punkt')
from nltk.collocations import BigramCollocationFinder # 從nltk 套件中載入BigramCollocationFinder
#文本數據集
corpus = ['i like apples and bananas','bananas are yellow', 'apples are red']

#處理文本數據，將每個文檔拆分成單詞
tokenized_corpus = [nltk.word_tokenize(doc) for doc in corpus] # 對每份文檔進行斷詞處理
#創建BigramCollocationFinder 對象
finder = BigramCollocationFinder.from_documents(tokenized_corpus) # 使用斷詞後的文本創建BigramCollocationFinder 對象
#計算PMI 值
bigram_measures = nltk.collocations.BigramAssocMeasures() # 創建BigramAssocMeasures 對象
pmi_scores = finder.score_ngrams(bigram_measures.pmi) # 計算bigram 的PMI 值
#印出前N個PMI值最高的bigram
N=8
print('運行結果')
for bigram , pmi in pmi_scores[:N]: # 印出前N 個PMI 值最高的bigram
  print(f"PMI({bigram}): {pmi:.2f}")
# Out:
# 運行結果
# PMI(('i', 'like')): 3.46
# PMI(('and', 'bananas')): 2.46
# PMI(('apples', 'and')): 2.46
# PMI(('are', 'red')): 2.46
# PMI(('are', 'yellow')): 2.46
# PMI(('like', 'apples')): 2.46
# PMI(('apples', 'are')): 1.46
# PMI(('bananas', 'are')): 1.46
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer # 從sklearn 套件中載入TfidfVectorizer
import pandas as pd # 載入pandas 套件，用於資料處理
#語料庫
corpus =[
    "This is the first document.",
    "This document is the second document.",
    "And this is the third one.",
    "Is this the first document?"]
#計算TF-IDF值
vectorizer = TfidfVectorizer() # 初始化TfidfVectorizer
X = vectorizer.fit_transform(corpus) # 對語料庫進行TF-IDF計算，得到特徵矩陣X
#將特徵矩陣轉換成DataFrame
data ={'word': vectorizer.get_feature_names_out(), 'tfidf': X.toarray().sum(axis=0).tolist()} # 計算每個詞的TF-IDF值
df = pd.DataFrame(data) # 創建DataFrame
#根據TF-IDF值降序排序
df_sorted = df.sort_values(by='tfidf', ascending=False ) # 根據tfidf 列降序排序
#輸出運行結果
print('運行結果')
print(df_sorted) # 印出排序後的DataFrame
# Out:
# 運行結果
#        word     tfidf
# 1  document  1.627206
# 3        is  1.316363
# 6       the  1.316363
# 8      this  1.316363
# 2     first  1.160572
# 5    second  0.538648
# 0       and  0.511849
# 4       one  0.511849
# 7     third  0.511849

# %%
import nltk # 載入nltk 套件
nltk.download('averaged_perceptron_tagger')
from nltk.tree import *
from nltk import pos_tag # 從nltk 中載入pos_tag 函數，用於詞性標註
from nltk import RegexpParser # 從nltk 中載入RegexpParserRegexpParser，用於正則表達式句法分析
#定義文本
text ="The quick brown fox jumps over the lazy dog"# 定義一段文本
#斷詞 詞性標註
tokens = nltk.word_tokenize(text) # 使用nltk 進行斷詞
tagged_tokens = pos_tag(tokens) # 使用pos_tag 進行詞性標註
#定義文法
grammar = "NP: {<DT>?<JJ>?<NN>}"# 定義一個名為grammar 的文法，用於句法分析
#初始化句法分析器
chunk_parser = RegexpParser(grammar) # 使用定義的文法初始化句法分析器
#進行句法分析
parse_tree = chunk_parser.parse(tagged_tokens) # 使用句法分析器進行句法分析
#繪製句法樹
#parse_tree.draw()
parse_tree.pretty_print() # 繪製句法樹
# Out:
#                                      S
#      ________________________________|______________________
#     |        |              NP               NP             NP
#     |        |       _______|________        |       _______|______
# jumps/VBZ over/IN The/DT quick/JJ brown/NN fox/NN the/DT lazy/JJ dog/NN
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#下載ckip套件
# !python --version
# !pip install ckiptagger
# !pip install tensorflow
# !pip install gdown
# Out:
# Python 3.10.12
# ...

# %%
from ckiptagger import data_utils
data_utils.download_data_gdown("./")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1efHsY16pxK0lBD2gYCgCTnv1Swstq771
# To: /content/drive/MyDrive/自然語言處理/data.zip
# 100%|██████████| 1.88G/1.88G [00:46<00:00, 40.5MB/s]

# %%
#ckip tagger套件
from ckiptagger import data_utils, construct_dictionary, WS, POS, NER
ws = WS("./data")
pos = POS("./data")
ner = NER("./data")
sentence_list = [
    "傅達仁今將執行安樂死，卻突然爆出自己20年前遭緯來體育台封殺，他不懂自己哪裡得罪到電視台。",
    "美國參議院針對今天總統布什所提名的勞工部長趙小蘭展開認可聽證會，預料她將會很順利通過參議院支持，成為該國有史以來第一位的華裔女性內閣成員。",
    "",
    "土地公有政策?？還是土地婆有政策。.",
    "… 你確定嗎… 不要再騙了……",
    "最多容納59,000個人,或5.9萬人,再多就不行了.這是環評的結論.",
    "科長說:1,坪數對人數為1:3。2,可以再增加。",
]

word_sentence_list = ws(sentence_list)
print(word_sentence_list)
pos_sentence_list = pos(word_sentence_list)
print(pos_sentence_list)
entity_sentence_list = ner(word_sentence_list, pos_sentence_list)
print(entity_sentence_list)
def print_word_pos_sentence(word_sentence, pos_sentence):
    assert len(word_sentence) == len(pos_sentence)
    for word, pos in zip(word_sentence, pos_sentence):
        print(f"{word}({pos})", end="\u3000")
    print()
    return

for i, sentence in enumerate(sentence_list):
    print()
    print(f"'{sentence}'")
    print_word_pos_sentence(word_sentence_list[i],  pos_sentence_list[i])
    for entity in sorted(entity_sentence_list[i]):
        print(entity)
# Out:
# /usr/local/lib/python3.10/dist-packages/ckiptagger/model_ws.py:106: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# /usr/local/lib/python3.10/dist-packages/ckiptagger/model_pos.py:56: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# /usr/local/lib/python3.10/dist-packages/ckiptagger/model_ner.py:57: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
# ...

# %%
# !pip install ckip-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 46.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 91.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.3 MB/s eta 0:00:00
# ...

# %%
from ckip_transformers import __version__# 載入ckip_transformers 套件的版本信息
from ckip_transformers.nlp import CkipWordSegmenter, CkipPosTagger, CkipNerChunker # 從ckip_transformers.nlp 中載入相應模組# 初始化 drivers
print("Initializing drivers ... WS") # 印出初始化Word Segmenter 的訊息
ws_driver = CkipWordSegmenter(model="albert-base") # 初始化Word Segmenter
print("Initializing drivers ... POS") # 印出初始化Pos Tagger 的訊息
pos_driver = CkipPosTagger(model="albert-base") #初始化Pos Tagger
def clean(sentence_ws , sentence_pos): # 定義一個名為clean 的函數，用於保留主要詞彙
  short_with_pos =[] # 初始化一個空串列short_with_pos pos，用於儲存含有詞性的短詞
  short_sentence =[] # 初始化一個空串列short_sentence sentence，用於儲存短詞
  stop_pos = set(['Nep', 'Nh', 'Nb']) # 定義一個包含特定詞性的集合stop_pos
  #逐詞進行處理
  for word_ws , word_pos in zip(sentence_ws ,sentence_pos):
    #只留名詞和動詞
    is_N_or_V = word_pos.startswith("V") or word_pos.startswith("N") # 判斷是否為名詞或動詞
    #去掉名詞裡的某些詞性
    is_not_stop_pos = word_pos not in stop_pos #判斷是否為特定詞性
    #只剩一個字的詞也不留
    is_not_one_charactor = not(len(word_ws) == 1 ) # 判斷是否只有一個字母 # 符合條件的詞加入串列
    if is_N_or_V and is_not_stop_pos and is_not_one_charactor:
      short_with_pos.append (f"{word_ws} ({word_pos})") # 將短詞和詞性以特定格式加入short_with_pos 串列
      short_sentence.append (f"{word_ws}") # 將短詞加入short_sentence 串列
  return (" ".join(short_sentence), " ".join(short_with_pos)) # 返回處理後的短詞和含詞性的短詞
def main():
  #語料庫
  with open('news.txt', mode='r') as file:
    text=file.read()
  print(text)
  text = text.split('\n')
  ws = ws_driver(text) # 進行斷詞
  pos = pos_driver(ws) # 進行詞性標注
  print()
  for sentence , sentence_ws , sentence_pos in zip(text, ws, pos): # 逐句進行處理
    print('原文')
    print(sentence) #印出原文
    (short, res) = clean(sentence_ws, sentence_pos) # 呼叫clean 函數進行處理
    print('斷詞後')
    print(short) # 印出斷詞後的短詞
    print ('斷詞後 詞性標注')
    print(res) # 印出含詞性的短詞
    print('-'*50) # 印出分隔線if __ name__===="__
if __name__== "__main__":
  main() # 呼叫main 函數執行主程序
# Out:
# Initializing drivers ... WS
# Initializing drivers ... POS
# 土敘強震過後三個星期，災區中的災區敘利亞，狀況脆弱，聯合國救援車隊抵達，初步估計全國370萬兒童，等於整個敘利亞的下一代，缺乏基本飲食飲水與住房。土耳其災區則是餘震頻傳，災區倖存者一無所有，想工作賺錢都沒辦法，總統艾爾多安卻在這時堅持：五月中如期辦大選。歐美分析他會用各種手法干預選舉，但民意已到谷底，結果難料。災區仍有零星奇蹟出現，受困21天的一匹土耳其馬竟存活，還能自己爬上瓦礫堆。
#
# 重機具開挖廢墟前一刻，才發現馬房沒塌！土耳其阿德亞曼省(Adıyaman)在大震後21天，再現奇蹟。受困3週的棕馬還能自己走上一層樓高的瓦礫堆！
#
# 路透社記者：「(祖孫)再度團聚，3週前他們一同從土耳其廢墟中被拉出來。」
#
# 土耳其地震災民 基利斯力：「我再也不會放你一個人了，我心愛的。」
#
# 老爺爺和五個月大的小孫女，一起被埋在哈泰省(Hatay)瓦礫堆下兩天半。小女娃的哭聲讓兩人獲救，之後她馬上被送到安卡拉治療，老爺爺茫然等待，終於得到通知，趕去安卡拉接回孫女。
#
# 土耳其地震災民 基利斯力：「她父母只留下她了。」
#
# 大家族也只剩下祖孫倆了。老爺爺失去所有親人又已年邁，政府補償金或許能領得稍多稍久一些，但土耳其南部更多青壯年的地震倖存者，未來就相當堪憂。好手好腳，但是工作在哪？
#
# 土耳其地震災民 法哈爾：「這條街曾是商業中心，我曾經有一家4層樓的地毯店。」
#
# 3月以來土耳其已又發生兩次規模5以上地震，最新一次是台北時間3月3日早上10點53分。兩起淺層餘震把至少29棟危樓震倒，再釀1死110傷。世界銀行估計，土耳其災損大約已達340億美元；罹難人數超過4萬5千人。
#
# 土耳其總統 艾爾多安(2023.03.01)：「就跟大家明說了吧，國家會做5月14日必須做的事。」
#
# 在國家遭遇大難後三個月，要如期舉行大選！艾爾多安掌權超過20年，有美國智庫推估，他將持續最近六、七年的整肅異己手段，大規模逮捕與控制媒體，讓自己勝選。但路透社訪問金融專家
#
# ，則認為艾爾多安選情不樂觀，主因是他一手主導的降息救通膨政策，澈底失敗，就算沒有地震，土耳其民眾日子都很難過。
#
# ...
